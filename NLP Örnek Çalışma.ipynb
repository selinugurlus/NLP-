# %%
#NPL ÖRNEK UYGULAMA:
#dataset: https://www.kaggle.com/datasets/cagrigungor/telefon-bankacl-mobile-bank

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('/content/banka.csv')
df=df[['sorgu','label']] #Bu şekilde yapılan işlem, belirli sütunları içeren yeni bir DataFrame oluşturur.
stopwords=['fakat','lakin','ancak','acaba', 'ama', 'aslında', 'az', 'bazı', 'belki', 'biri', 'birkaç', 'birşey', 'biz', 'bu', 'çok', 'çünkü', 'da', 'daha', 'de', 'defa', 'diye', 'eğer', 'en', 'gibi', 'hem', 'hep', 'hepsi', 'her', 'hiç', 'için', 'ile', 'ise', 'kez', 'ki', 'kim', 'mı', 'mu', 'mü', 'nasıl', 'ne', 'neden', 'nerde', 'nerede', 'nereye', 'niçin', 'niye', 'o', 'sanki', 'şey', 'siz', 'şu', 'tüm', 've', 'veya', 'ya', 'yani']

message=input("Yapmak istediğiniz işlemi yazınız.")
messagedf=pd.DataFrame({"sorgu":message,"label":0},index=[42])
df=pd.concat([df,messagedf],ignore_index=True) #Bu satır, pd.concat() fonksiyonunu kullanarak iki DataFrame'i birleştiriyor.ignore_index=True ise, birleştirilen DataFrame'in indexlerinin yeniden düzenlenmesini sağlar.

for word in stopwords:
  word=" "+word+" " #Kelime içindeki heceleri stopword olarak almaması için.
  df['sorgu']=df['sorgu'].str.replace(word," ") #Bu 'stopword' kelimesinin bulunduğu herhangi bir eşleşmeyi boş bir dizeyle değiştirir.

cv=CountVectorizer(max_features=50)

x=cv.fit_transform(df['sorgu']).toarray()
y=df['label']

tahmin=x[-1].copy() #x değişkenindeki son örneği (satırı) bir kopya olarak tahmin değişkenine kopyalar. Bu işlem genellikle, modelin eğitiminde kullanılan veri setinden ayrılan ve tahmin edilecek yeni bir örneği temsil eder.

x=x[0:-1] #son satı hariç en baştan
y=y[0:-1]

x_train, x_test, y_train, y_test=train_test_split(x,y,random_state=21,train_size=0.7)

rf=RandomForestClassifier()
model=rf.fit(x_train,y_train)
skor=model.score(x_test,y_test)

sonuc=model.predict([tahmin])
print("Sonuc:",sonuc,"Skor:",skor)
# Out:
# Yapmak istediğiniz işlemi yazınız.kartım kayboldu
# Sonuc: ['kartkayip'] Skor: 1.0
